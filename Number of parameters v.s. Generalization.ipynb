# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid

import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
transform = transforms.ToTensor()

# %%
train_data_set = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_data_set = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# %%
train_data_set
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ./data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
train_loader = DataLoader(train_data_set, batch_size=500, shuffle=True)

test_loader = DataLoader(test_data_set, batch_size=100, shuffle=False)

# %%
class Model1(nn.Module):
    def __init__(self, in_features=784, h1=5,h2=9, out_features=10):
        super().__init__()
        self.fc1 = nn.Linear(in_features,h1)    
        self.fc2 = nn.Linear(h1, h2)
        self.out = nn.Linear(h2, out_features)
        
        
    def forward(self, x):
        x = x.reshape(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        return x

class Model2(nn.Module):
    def __init__(self, in_features=784, h1=25,h2=50, out_features=10):
        super().__init__()
        self.fc1 = nn.Linear(in_features,h1)    
        self.fc2 = nn.Linear(h1, h2)
        self.out = nn.Linear(h2, out_features)
        
        
    def forward(self, x):
        x = x.reshape(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        return x
    
class Model3(nn.Module):
    def __init__(self, in_features=784, h1=50,h2=100, out_features=10):
        super().__init__()
        self.fc1 = nn.Linear(in_features,h1)    
        self.fc2 = nn.Linear(h1, h2)
        self.out = nn.Linear(h2, out_features)
        
        
    def forward(self, x):
        x = x.reshape(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        return x
    
class Model4(nn.Module):
    def __init__(self, in_features=784, h1=60,h2=120, out_features=10):
        super().__init__()
        self.fc1 = nn.Linear(in_features,h1)    
        self.fc2 = nn.Linear(h1, h2)
        self.out = nn.Linear(h2, out_features)
        
        
    def forward(self, x):
        x = x.reshape(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        return x

class Model5(nn.Module):
    def __init__(self, in_features=784, h1=100,h2=200, out_features=10):
        super().__init__()
        self.fc1 = nn.Linear(in_features,h1)    
        self.fc2 = nn.Linear(h1, h2)
        self.out = nn.Linear(h2, out_features)
        
        
    def forward(self, x):
        x = x.reshape(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        return x

class Model6(nn.Module):
    def __init__(self, in_features=784, h1=150,h2=300, out_features=10):
        super().__init__()
        self.fc1 = nn.Linear(in_features,h1)    
        self.fc2 = nn.Linear(h1, h2)
        self.out = nn.Linear(h2, out_features)
        
        
    def forward(self, x):
        x = x.reshape(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        return x

class Model7(nn.Module):
    def __init__(self, in_features=784, h1=200,h2=400, out_features=10):
        super().__init__()
        self.fc1 = nn.Linear(in_features,h1)    
        self.fc2 = nn.Linear(h1, h2)
        self.out = nn.Linear(h2, out_features)
        
        
    def forward(self, x):
        x = x.reshape(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        return x
    
class Model8(nn.Module):
    def __init__(self, in_features=784, h1=250,h2=500, out_features=10):
        super().__init__()
        self.fc1 = nn.Linear(in_features,h1)    
        self.fc2 = nn.Linear(h1, h2)
        self.out = nn.Linear(h2, out_features)
        
        
    def forward(self, x):
        x = x.reshape(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        return x

class Model9(nn.Module):
    def __init__(self, in_features=784, h1=280,h2=560, out_features=10):
        super().__init__()
        self.fc1 = nn.Linear(in_features,h1)    
        self.fc2 = nn.Linear(h1, h2)
        self.out = nn.Linear(h2, out_features)
        
        
    def forward(self, x):
        x = x.reshape(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        return x

class Model10(nn.Module):
    def __init__(self, in_features=784, h1=350,h2=600, out_features=10):
        super().__init__()
        self.fc1 = nn.Linear(in_features,h1)    
        self.fc2 = nn.Linear(h1, h2)
        self.out = nn.Linear(h2, out_features)
        
        
    def forward(self, x):
        x = x.reshape(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        return x

# %%
# Hyper-parameters 
input_size = 784 # 28x28
max_epochs = 15
learning_rate = 0.001
kernel_size = 4
num_epochs = 10
dropout = 0.25

# %%
def trainFunc(model,num_epochs,train_batch_size):
    model.train()
    train_load = train_loader(train_batch_size)
    n_total_steps = len(train_loader)
    train_losses = []
    train_epoch = []
    train_acc = []
    not_converged =True
    epoch = 0
    trainAvgLossArr =[]
    trainAvgAccArr =[]
    while not_converged:
        epoch += 1
        n_correct = 0
        n_samples = 0
        lossSum = 0
        totalacc =0

        for i, (images, labels) in enumerate(train_loader):  
            images, labels = Variable(images),Variable(labels)
            # zero the parameter gradients
            optimizer.zero_grad()
            # Forward pass
            prediction = model(images)
            loss = loss_func(prediction, labels)
            lossSum += loss.detach().numpy()
            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            _, predicted = torch.max(prediction.data, 1)
            n_samples += labels.size(0)
            n_correct += (predicted == labels).sum().item()
            acc = 100.0 * n_correct / n_samples
            totalacc += acc
            
            

            if (i+1) % 100 == 0:
                print (f'Epoch [{epoch}/{num_epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.4f}',end='\r',flush=True)
                train_epoch.append(epoch)
                train_losses.append(loss.item())
                print(f'Epoch [{epoch}/{num_epochs}], Accuracy : {acc} %',end='\r',flush=True)
                train_acc.append(acc)

                if epoch == num_epochs:
                        print(f"Max Epoch Reached, Loss: {loss.item():.4f}, Accuracy:{acc:2f}%")
                        not_converged = False
                elif (epoch > 5) and  (train_losses[-1] < 0.001):
                    if abs(train_losses[-3] - train_losses[-2]) < 1.0e-05 and abs(train_losses[-2] - train_losses[-1]) < 1.0e-05:
                        print("Convergeance reached for loss:",train_losses[-1])
                        not_converged = False
        epochAcc = totalacc/(i+1)
        trainAvgLossArr.append(lossSum/n_total_steps)    
        trainAvgAccArr.append(epochAcc)
        
                        
    return train_epoch,train_losses,train_acc,trainAvgLossArr,trainAvgAccArr

# %%
def testFunc(model): 
    model.eval()
    with torch.no_grad():
        n_correct = 0
        n_samples = 0
        testLoss = 0
        count = 0
        for images, labels in test_loader:
            prediction = model(images)
            tLoss = loss_func(prediction, labels)
            testLoss += tLoss
            # max returns (value ,index)
            _, predicted = torch.max(prediction.data, 1)
            n_samples += labels.size(0)
            n_correct += (predicted == labels).sum().item()
            count += 1

        testLoss /= count
        netTest_acc1 = 100.0 * n_correct / n_samples

        print(f'Accuracy of the network:{model._get_name()} on the test images: {netTest_acc1:.2f} % & loss of the network:{testLoss:.4f}')
        return netTest_acc1,testLoss

# %%
modelArr = [Model1,Model2,Model3,Model4,Model5,Model6,Model7,Model8,Model9,Model10]
allTrainLoss = {}
allTrainAcc = {}
allTestLoss = {}
allTestAcc = {}
allModelPar = {}
for i in range (len(modelArr)):
        j = copy.deepcopy(i)
        torch.manual_seed(1)
        j = modelArr[i]()

        loss_func = nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(j.parameters(), lr=learning_rate) 

        a=[]
        for k in j.parameters():
            a.append(torch.numel(k))
        modelTotalPrams = np.sum(a)
        print(f'Total no of parameters in Model{j._get_name()} :{modelTotalPrams}')

        train_epoch,train_losses,train_acc,trainAvgLoss = trainFunc(j,num_epochs)

        testAcc,testLoss = testFunc(j)

        allTrainLoss[j._get_name()] = trainAvgLoss
        allTrainAcc[j._get_name()] = train_acc
        allTestLoss[j._get_name()] = testLoss
        allTestAcc[j._get_name()] = testAcc     
        allModelPar[j._get_name()] = modelTotalPrams
# Out:
# Total no of parameters in ModelModel1 :4079
# Max Epoch Reached, Loss: 0.5430, Accuracy:85.548000%
# Accuracy of the network:Model1 on the test images: 85.71 % & loss of the network:0.4748
# Total no of parameters in ModelModel2 :21435
# Max Epoch Reached, Loss: 0.1423, Accuracy:95.800000%
# Accuracy of the network:Model2 on the test images: 95.33 % & loss of the network:0.1517
# Total no of parameters in ModelModel3 :45360
# Max Epoch Reached, Loss: 0.1078, Accuracy:96.848000%
# Accuracy of the network:Model3 on the test images: 96.35 % & loss of the network:0.1187
# Total no of parameters in ModelModel4 :55630
# Max Epoch Reached, Loss: 0.0848, Accuracy:97.382000%
# Accuracy of the network:Model4 on the test images: 96.81 % & loss of the network:0.1047
# Total no of parameters in ModelModel5 :100710
# Max Epoch Reached, Loss: 0.0410, Accuracy:98.194000%
# Accuracy of the network:Model5 on the test images: 97.20 % & loss of the network:0.0893
# ...

# %%
#plot loss vs param
model_TrainLoss = [np.min(allTrainLoss['Model1']),np.min(allTrainLoss['Model2']),
              np.min(allTrainLoss['Model3']),np.min(allTrainLoss['Model4']),
              np.min(allTrainLoss['Model5']),np.min(allTrainLoss['Model6']),
              np.min(allTrainLoss['Model7']),np.min(allTrainLoss['Model8']),
              np.min(allTrainLoss['Model9']),np.min(allTrainLoss['Model10'])     
            ]
model_Tpara = [allModelPar['Model1'],allModelPar['Model2'],allModelPar['Model3'],
                allModelPar['Model4'],allModelPar['Model5'],allModelPar['Model6'],
                allModelPar['Model7'],allModelPar['Model8'],allModelPar['Model9'],
                allModelPar['Model10']
                ]
model_Testloss = [allTestLoss['Model1'],allTestLoss['Model2'],allTestLoss['Model3'],allTestLoss['Model4'],allTestLoss['Model5'],
                  allTestLoss['Model6'],allTestLoss['Model7'],allTestLoss['Model8'],allTestLoss['Model9'],allTestLoss['Model10']     
                ]

# %%
plt.figure(figsize=(6,4))
plt.scatter(model_Tpara, model_TrainLoss, color = "r")
plt.scatter(model_Tpara, model_Testloss, color = "g")
plt.title('Model Loss Comparision')
plt.legend(['Train Loss', 'Test Loss'])
plt.xlabel('Parameters')
plt.ylabel('Loss')
plt.show()

# %%
#plot Acc vs paramteres
model_TrainAcc= [np.max(allTrainAcc['Model1']),np.max(allTrainAcc['Model2']),
              np.max(allTrainAcc['Model3']),np.max(allTrainAcc['Model4']),
              np.max(allTrainAcc['Model5']),np.max(allTrainAcc['Model6']),
              np.max(allTrainAcc['Model7']),np.max(allTrainAcc['Model8']),
              np.max(allTrainAcc['Model9']),np.max(allTrainAcc['Model10'])     
                ]
model_TestAcc = [allTestAcc['Model1'],allTestAcc['Model2'],allTestAcc['Model3'],allTestAcc['Model4'],allTestAcc['Model5'],
                  allTestAcc['Model6'],allTestAcc['Model7'],allTestAcc['Model8'],allTestAcc['Model9'],allTestAcc['Model10']     
                ]

# %%
plt.figure(figsize=(6,4))
plt.scatter(model_Tpara, model_TrainAcc, color = "r")
plt.scatter(model_Tpara, model_TestAcc , color = "g")
plt.title('Model Acc Comparision')
plt.legend(['Train Accuracy', 'Test Accuracy'])
plt.xlabel('Parameters')
plt.ylabel('Accuracy')
plt.show()
